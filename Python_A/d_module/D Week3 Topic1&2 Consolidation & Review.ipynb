# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import otter
grader = otter.Notebook()

# %% [markdown]
# # D | Week 3: Practice Consolidation & Review
#
# ------
#
# ### Instructions:
#
# - Complete 50 points worth of questions to pass the assessment
#   - You can attempt any number of questions and in any order provided you pass at least 50 points.
# - Develop and check your answers in the spaces provided.
#   - Do not remove any variables other provided markings already present in the answer spaces.
#   - Do not make any changes to this notebook outside of the answer spaces provided.
#
# #### Submitting
#
# - Upload your .ipynb file to Gradescope (Make sure to restart the kernel and run all before you submit)
# - You can submit as many times as needed
# - When reviewing results, ignore any results listed under "Public Tests"
#
# For more information, see the assessment page. We have also provided an example question below for clarity.

# %% [markdown]
# #### Question 1&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;(3 Points)
# Study the 2 classes: Member and PremiumMember. Identify the relation between them and make the necessary changes to the class to implement the relation. Pay attention to creating accessors(getters) and mutators(setters). Place the methods in the correct class.
#
# **Hint: change private to protected access modifier where applicable**
#
# <pre><code>
# class Member:
#     def __init__(self,fname,lname,memberid):
#         self.__fname=fname
#         self.__lname=lname
#         self.__memberid=memberid
#
# class PreminumMember:
#     def __init__(self,fname,lname,memberid,premium_ref_id):
#         self.__fname=fname
#         self.__lname=lname
#         self.__memberid=memberid
#         self.__premium_id=premium_ref_id
#
# </code></pre>

# %%
# Write your solution here
class Member:
    def __init__(self,fname,lname,memberid):
        self._fname=fname
        self._lname=lname
        self._memberid=memberid

class PreminumMember(Member):
    def __init__(self,fname,lname,memberid,premium_ref_id):
        Member.__init__(self,fname,lname,memberid)
        self.__premium_id=premium_ref_id

# %% [markdown]
# #### Question 2&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;(3 Points)
#
# The class TwoDShape is given to you below.
#
# <pre><code>class TwoDShape:
#     def __init__(self,name):
#         self.name=name
#         self.area=0
#         self.perimeter=0
#
#     def get_area(self):
#         return self._area
#
#     def get_perimeter(self):
#         return self._perimeter
#
#     def calculate_area(self):
#         pass
#
#     def calculate_perimeter(self):
#         pass
# </code></pre>
#
# Create 2 classes Circle and Square which are both TwoDShapes. Circle must have the property radius and square must have the property side. Override the 2 methods <pre><code>calculate_area, calculate_perimeter
# </code></pre> with the correct formula for each of the 2 shapes. Pass 'Circle' and 'Square' as names to the base constructor

# %%
from math import pi 

class TwoDShape:
    def __init__(self,name):
        self.name=name
        self._area=0
        self._perimeter=0

    def get_area(self):
        return self._area

    def get_perimeter(self):
        return self._perimeter

    def calculate_area(self):
        pass

    def calculate_perimeter(self):
        pass
    
class Circle(TwoDShape):
    def __init__(self, radius):
        super().__init__("Circle")
        self.radius = radius
        
    def get_area(self):
        return self._area

    def get_perimeter(self):
        return self._perimeter

    def calculate_area(self):
        self._area = pi * self.radius**2

    def calculate_perimeter(self):
        self._perimeter = 2 * pi * self.radius
        
class Square(TwoDShape):
    def __init__(self, side):
        super().__init__("Square")
        self.side = side
        
    def get_area(self):
        return self._area

    def get_perimeter(self):
        return self._perimeter

    def calculate_area(self):
        self._area = self.side**2

    def calculate_perimeter(self):
        self._perimeter = 4 * self.side
    
c1=Circle(2)
s1=Square(4)
c1.calculate_perimeter()
c1.calculate_area()
s1.calculate_perimeter()
s1.calculate_area()
s1.calculate_perimeter()
# Write your solution here
print(c1.get_area())
print(s1.get_area())
print(c1.get_perimeter())
print(s1.get_perimeter())
# Out:
# 12.566370614359172
# 16
# 12.566370614359172
# 16

# %% [markdown]
# #### Question 3&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;(3 Points)
# Extend the Pyramid class provided below by using magic methods to return the following statement when the object is cast as string <code> "The height of the pyramid is xx units and it's base has the width of xx units and length of xx units. The total volume is xx cubic units"</code>. Also include the functionality to compare Pyramid objects based on their volume.<br>
# **Hint: Refer to arithmetic magic methods lt,eq**
#
#
# <pre><code>class Pyramid:
#     def __init__(self,height,base_length,base_width):
#         self.__height=height
#         self.__base_length=base_length
#         self.__base_width=base_width
#         self.__volume = height*base_length*base_width/3</code></pre>

# %%
# Write your solution here
class Pyramid:
    def __init__(self,height,base_length,base_width):
        self.__height=height
        self.__base_length=base_length
        self.__base_width=base_width
        self.__volume = height*base_length*base_width/3
        
    def __repr__(self):
        return f"The height of the pyramid is {self.__height} units and it's base has the width of {self.__base_width} units and length of {self.__base_length} units. The total volume is {self.__volume} cubic units"

    def get_volume(self):
        return self.__volume
    
    def __lt__(self, obj):
        return self.__volume < obj.get_volume()
    
p3=Pyramid(2,3,3)
p2=Pyramid(3,1,4)
p1=Pyramid(5,2,3)
shapes_list=[p1,p2,p3]
shapes_list.sort()

# %% [markdown]
# #### Question 4&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;(3 Points)
# For the class definitions provided below, create the following relationships
#
# Building has a Manger (Aggregation)
# BuildingExpense is part of Building (Composition)
#
# <pre><code>import datetime
#
# class BuildingExpense:
#     def __init__(self,building_id,issue_date,amount,authorised_by):
#         self.__amount = amount
#         self.__authorised_by=authorised_by
#         self.__building_id = building_id
#         self.__issue_date = issue_date
#
# class Building:
#     def __init__(self,building_id,name,location,manager,amount,authorised_by):
#         self.__building_id=building_id
#         self.name=name
#         self.__location=location
#         self.manager = manger
#         issue_date=datetime.datetime.today()
#
# class Manager:
#     def __init__(self,name,emp_id,contact_no):
#         self.__name=name
#         self.__emp_id=emp_id
#         self.__contact_no=contact_no
#
# manager=None
# building=None</code></pre>
#
# Create a manager object with name,emp_id and contact_no as "John","1111","04111111111"
#
# Create a Building named "The O" at the location "34, Sufton St, Karaville SA 5076" with John as manager
# The Building expense associated with "The O" is $250000 and authorised by "Mc lane" and it's id is "B001"

# %%
# Write your solution here
import datetime

class BuildingExpense:
    def __init__(self,building_id,issue_date,amount,authorised_by):
        self.__amount = amount
        self.__authorised_by=authorised_by
        self.__building_id = building_id
        self.__issue_date = issue_date

class Building:
    def __init__(self,building_id,name,location,manager,amount,authorised_by):
        self.__building_id=building_id
        self.name=name
        self.__location=location
        self.manager = manager
        issue_date=datetime.datetime.today()
        self.__building_expence = BuildingExpense(building_id, issue_date, amount, authorised_by)

class Manager:
    def __init__(self,name,emp_id,contact_no):
        self.__name=name
        self.__emp_id=emp_id
        self.__contact_no=contact_no
        
manager1 = Manager("John","1111","04111111111")
building1 = Building("B001", "The O", "34, Sufton st, Karaville SA 5076", manager, 250000, "Mc lane")

# %% [markdown]
# #### Question 5&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;(3 Points)
# Consider the following class definition.
#
#
# Update it by keeping best practices in mind
# <pre><code>
# class Player:
#     def __init__(self,name,id,location):
#         self.name=name
#         self.id=id
#         self.location=location
#         self.maxLifes=5</code></pre>
#
# For the given class, name and id can't be updated after creation. Location can be updated, given some validation logic. The Attribute maxLife refers to number of retries that players have before game over and is fixed for all players and not able to be updated.

# %%
# Write your solution here

class Player:
    def __init__(self,name,id,location):
        self._name='Pl'
        self._id='123'
        self._location=location
        self.__maxLifes=5

player=Player('Pl','123','loc')

# %% [markdown]
# #### Question 6&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;(5 Points)
# There are 2 classes Fruit and Fruitbasket. Refer to the class definition below. Identify the relationship between the classes and populate the variable relation_fruit_basket with one of the following values <code>['Inheritance','Composition','Arrgregation']</code>. Add validation logic to set_price for Fruit class to accept positive numbers less than 20 only. Create 5 Fruits with the properties given below
# <pre>
# Apple,3
# Banana,2.5
# Pear,2
# Orange,3
# Mango,8
# </pre>
#
# <pre><code>class Fruit:
#     def __init__(self,name,price):
#         self.__name=name
#         self.__price=price
#
#     def get_name(self):
#         return self.__name
#
#     def get_price(self):
#         return self.__price
#
#     def set_price(self,price)
#         self.__price=price
#
# class Fruitbasket:
#     def __init__(self):
#         self.__basket=[]
#         self.__weight=0
#         self.__cost=0
#
#     def get_weight(self):
#         return self.__weight
#
#     def get_cost(self):
#         return self.__cost
#
#     def add_fruit_to_basket(self,fruit,weight):
#         self.__basket.append(fruit)
#         self.__weight+=weight
#         self.__cost+=weight*fruit.get_price()
#
# Create a FruitBasket and add 1 unit of weight of each of the listed fruit. Print the statement <code> The total cost of the basket is xxAUD and it weighs xxkg </code> after all the fruits are added.

# %%
relation_fruit_basket='Arrgregation'
basket=None

# Write your solution here



class Fruit:
    def __init__(self,name,price):
        self.__name=name
        self.__price=price

    def get_name(self):
        return self.__name

    def get_price(self):
        return self.__price

    def set_price(self,price):
        if price < 20 and price > 0:
            self.__price=price
            return True
        return False

class Fruitbasket:
    def __init__(self):
        self.__basket=[]
        self.__weight=0
        self.__cost=0

    def get_weight(self):
        return self.__weight

    def get_cost(self):
        return self.__cost

    def add_fruit_to_basket(self,fruit,weight):
        self.__basket.append(fruit)
        self.__weight+=weight
        self.__cost+=weight*fruit.get_price()
        
    def __str__(self):
        return f"The total cost of the bassket is {self.__cost}AUD and it weighs {self.__weight}kg  after all the fruits are added"

fruit1=Fruit('Apple',3)
fruit2=Fruit('Banana',2.5)
fruit3=Fruit('Pear',2)
fruit4=Fruit('Orange',3)
fruit5=Fruit('Mango',8)    
    
basket = Fruitbasket()
basket.add_fruit_to_basket(fruit1, 1)
basket.add_fruit_to_basket(fruit2, 1)
basket.add_fruit_to_basket(fruit3, 1)
basket.add_fruit_to_basket(fruit4, 1)
basket.add_fruit_to_basket(fruit5, 1)

print(basket)
print(fruit1.set_price(-1))
print(fruit1.set_price(20.34))
# Out:
# The total cost of the bassket is 18.5AUD and it weighs 5kg  after all the fruits are added
# False
# False

# %% [markdown]
# #### Question 7&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;(5 Points)
# The library of Ikmich is developing a software to automate book borrowing features for its users.
# Implement the following classes as per the requirements:
#
# Class for Authors of books
# <pre>
# Author
#     --first_name
#     --last_name
#     --date_of_birth
#     --description
#     +__init__(first_name,last_name,date_of_birth)
#     +get_name()
#     +get_date_of_birth()
#     +set_description()
#     +get_description()
# </pre>
# get_name must return 'first_name'+ ' ' + 'last_name'. description must be initilased to None
#
# Class for Books
# <pre>
# Book
#     --name
#     --author
#     --published_year
#     --category
#     --borrowed_date
#     --due_date
#     +__init__(name,author,published_year,category)
#     +get_name()
#     +get_author()
#     +get_year_of_publication()
#     +get_category()
#     +get_borrowed_date()
#     +get_due_date()
#     +renew_book(no_of_days)
# </pre>
# author is an object of Author class. borrowed_date and returned_date is initialised to None. The method renew_book must add no_of_days to due_date. If due_date is none when renewing book, set it to current date before adding days
#
# **Hint: Use datetime.datetime.today() for current date and use datetime.timedelta(days=n) object to add days to a datetime.date object**
#
# Identify the relationship between Author and Book and populate the variable <code>relation_auth_book</code> with one of the following values <code>['Inheritance','Composition','Arrgregation']</code>

# %%
import datetime
relation_auth_book='Arrgregation'

class Author:
    def __init__(self,first_name,last_name,date_of_birth):
        self.__first_name = first_name
        self.__last_name = last_name
        self.__date_of_birth = date_of_birth
        self.__description = ""
        
    def get_name(self):
        return self.__first_name + " " + self.__last_name
    
    def get_date_of_birth(self):
        return self.__date_of_birth
    
    def set_description(self, description):
        self.__description = description
        
    def get_description(self):
        return self.__description
class Book:
    def __init__(self,name,author,published_year,category):
        self.__name = name
        self.__author = author
        self.__published_year = published_year
        self.__category = category
        self.__borrowed_date = None
        self.__due_date = None

    def get_name(self):
        return self.__name
    
    def get_author(self):
        return self.__author
    
    def get_year_of_publication(self):
        return self.__published_year
    
    def get_category(self):
        return self.__category
    
    def get_borrowed_date(self):
        return self.__borrowed_date
    
    def get_due_date(self):
        return self.__due_date
    
    def renew_book(no_of_days):
        if self.__due_date == None:
            self.__due_date = datetime.datetime.today()
            
        self.__due_date.timedelta(days=no_of_days) 

auth1=Author('First','last','1/2/1978')
auth1.set_description('This is a sample')
# Write your solution here
book1=Book('B_name',auth1,'2020','category')

# %% [markdown]
# #### Question 8&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;(5 Points)
# The library of Ikmich is developing a software to automate book borrowing features for its users.
#
# Implement the following classes as per the requirements:
#
# Class for public who are registered at the the library. They can borrow up to 3 books at once. They can borrow a book for 14 days at once. They can renew the book before the due date.
# <pre>
# Member
#     +name
#     +address
#     +borrowing_capacity
#     -current_borrowed_books
#     -membership_expiry_date
#     +__init__(name,adderss,membership_expiry_date)
#     +get_current_borrowed_books()
#     +borrow_book(book)
#     +renew_book()
#     +renew_membership(no_of_days)
#     +get_membership_expiry_date()
# </pre>
#
# Class for students who are registered at the the library. They can borrow up to 4 books at once. They can borrow a book for 21 days at once. They can renew the book before the due date.
# <pre>
# StudentMember(Member)
#     +name
#     +address
#     +borrowing_capacity
#     -current_borrowed_books
#     -membership_expiry_date
#     --student_id
#     +__init__(name,adderss,membership_expiry_date,student_id)
#     +get_student_id
#     +get_current_borrowed_books()
#     +borrow_book(book)
#     +renew_book()
#     +renew_membership(no_of_days)
#     +get_membership_expiry_date()
# </pre>
#
# Class for teachers who are registered at the the library. They can borrow up to 6 books at once. They can borrow a book for 30 days at once. They can renew the book before the due date.
# <pre>
# StaffMember(Member)
#     +name
#     +address
#     +borrowing_capacity
#     -current_borrowed_books
#     -membership_expiry_date
#     --staff_id
#     +__init__(name,adderss,membership_expiry_date,staff_id)
#     +get_staff_id
#     +get_current_borrowed_books()
#     +borrow_book(book)
#     +renew_book()
#     +renew_membership(no_of_days)
#     +get_membership_expiry_date()
# </pre>
#
# Store borrowing_capacity and borrow_duration as private class variables.The property current_borrowed_books must be initialised to empty list. To borrow a book (borrow_book), use renew_book described in the question above with days equal to borrow_duration. If the borrwing capacity is reached, return False else return True. Override the renew_book and borrow_book methods for each member class appropriately to accept a book object defined in the question above and invoke its renew_book method.

# %%
# Write your solution here

import datetime

class Member:
    __borrowing_capacity = 3
    __borrow_duration = 14
    
    def __init__(self,name,address,membership_expiry_date):
        self.name = name
        self.address = address
        self._current_borrowed_books = []
        self._membership_expiry_date = membership_expiry_date
    
    def get_current_borrowed_books(self):
        return self._current_borrowed_books
    
    def borrow_book(self, book):
        if (len(self._current_borrowed_books) < Member.__borrowing_capacity):
            self._current_borrowed_books.append(book)
            return True
        return False
    
    def renew_book(self):
        return Member.__borrow_duration
        
    def renew_membership(self, no_of_days):
        self._membership_expiry_date = self._membership_expiry_date + datetime.timedelta(days=no_of_days)  
        
    def get_membership_expiry_date(self):
        return self._membership_expiry_date
    
class StudentMember(Member):
    
    __borrowing_capacity = 4
    __borrow_duration = 21
    
    def __init__(self,name,adderss,membership_expiry_date,student_id):
        super().__init__(name,adderss,membership_expiry_date)
        self.__student_id = student_id
        
    def get_student_id(self):
        return self.__student_id
    
    def borrow_book(self, book):
        if (len(self._current_borrowed_books) < StudentMember.__borrowing_capacity):
            self._current_borrowed_books.append(book)
            return True
        return False
    
    def renew_book(self):
        return StudentMember.__borrow_duration

class StaffMember(Member):
    __borrowing_capacity = 6
    __borrow_duration = 30
    
    def __init__(self, name,adderss,membership_expiry_date,staff_id):
        super().__init__(name,adderss,membership_expiry_date)
        self.__staff_id = staff_id
    
    def get_staff_id(self):
        return self.__staff_id
    
    def borrow_book(self, book):
        if (len(self._current_borrowed_books) < StaffMember.__borrowing_capacity):
            self._current_borrowed_books.append(book)
            return True
        return False
    
    def renew_book(self):
        return StaffMember.__borrow_duration
    
q8m=Member('name','address',datetime.date(2022,1,1))
st_m=StudentMember('name1','address1',datetime.date(2022,1,1),'a001')
stff_m=StaffMember('name2','address2',datetime.date(2022,1,1),'a-001')

# print(st_m.borrow_book('Book1'))
# print(st_m.borrow_book('Book2'))
# print(st_m.borrow_book('Book3'))
# print(st_m.borrow_book('Book4'))
# print(st_m.borrow_book('Book5'))
# print(st_m.renew_book())
# print(st_m.get_membership_expiry_date())
# print(st_m.renew_membership(5))
# print(st_m.get_membership_expiry_date())

# %% [markdown]
# #### Question 9&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;(5 Points)
# EYMC is a company that manages reservations of the fictional Hotel Wonderful_H. They have a system that recognises 3 types of reservations. Reservations for a hotel room, reservations for a conference room and reservations for a party hall. For auditing purposes, they also utilise the base class reservation.
#
# The class template for the classes is given below. Implement the 3 classes
#
# <pre>
#  Reservation
#      static --reservation_count
#      +location
#      +date
#      +contact_no
#      +__init__(location,date,contact_no)
#      +get_reservation_count()
#
#  RoomReservation(Reservation)
#      --no_of_beds
#      --includes_breakfast
#      +__init__(location,date,contact_no,no_of_beds,includes_breakfast)
#      +get_no_of_beds()
#      +get_includes_breakfast()
#
#  ConferenceReservations(Reservation)
#      +event_name
#      --max_capacity
#      --av_equipment_required
#      +__init__(location,date,contact_no,max_capacity,av_equipment_required)
#      +get_max_capacity()
#      +get_av_equipment_required()
#
#  PartyHallReservation(Reservation)
#      --party_theme
#      --guest_capacity
#      --catering_required
#      +__init__(location,date,contact_no,party_theme,guest_capacity,catering_required)
#      +get_catering_required()
#      +get_guest_capacity()
# </pre>
#
# <code>includes_breakfast, av_equipment_required, catering_required</code> are all boolean values and are optional. Default argument is False. Reservation also has a static(class) private variable for counting the total number of reservations. Everytime a reservation is created, it must be incremented
#
# Make the following Reservations
#     <pre><code>RoomReservation("Palm'de'orre, suite 3",'30/12/2022','0412345678',2)
# ConferenceReservation("Float Topps Buiness suite 3",'03/12/2022','0412345678',250,True)
# PartyHallReservation("Kids World, Fun castle",'05/11/2022','043333333','Birthday',50,True)</code></pre>

# %%
reservation1=None
reservation2=None
reservation3=None

# Write your solution here
class Reservation:
    reservation_count = 0
    
    def __init__(self, location, date, contract_no):
        self.location = location
        self.date = date
        self.contract_no = contract_no
        Reservation.reservation_count += 1
        
    def get_reservation_count(self):
        return Reservation.reservation_count
    
class RoomReservation(Reservation):
    def __init__(self, location,date,contact_no,no_of_beds,includes_breakfast = False):
        super().__init__(location, date, contact_no)
        self.__no_of_beds = no_of_beds
        self.__includes_breakfast = includes_breakfast
        
    def get_no_of_beds(self):
        return self.__no_of_beds
    
    def get_includes_breakfast(self):
        return self.__includes_breakfast
    
class ConferenceReservation(Reservation):
    def __init__(self, location,date,contact_no,max_capacity,av_equipment_required = False):
        super().__init__(location, date, contact_no)
        self.event_name = None
        self.__max_capacity = max_capacity
        self.__av_equipment_required = av_equipment_required
        
    def get_max_capacity(self):
        return self.__max_capacity
    
    def get_av_equipment_required(self):
        return self.__av_equipment_required

class PartyHallReservation(Reservation):
    def __init__(self, location,date,contact_no,party_theme,guest_capacity,catering_required = False):
        super().__init__(location, date, contact_no)
        self.__party_theme = party_theme
        self.__guest_capacity = guest_capacity
        self.__catering_required = catering_required
        
    def get_catering_required(self):
        return self.__catering_required
    
    def get_guest_capacity(self):
        return self.__guest_capacity
    
reservation1 = RoomReservation("Palm'de'orre, suite 3",'30/12/2022','0412345678',2)
reservation2 = ConferenceReservation("Float Topps Buiness suite 3",'03/12/2022','0412345678',250,True)
reservation3 = PartyHallReservation("Kids World, Fun castle",'05/11/2022','043333333','Birthday',50,True)
print(reservation1.get_reservation_count())
print(reservation2.get_reservation_count())
print(reservation3.get_reservation_count())
# Out:
# 3
# 3
# 3

# %% [markdown]
# #### Question 10&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;(5 Points)
#
# Create the following classes
# ![Picture2.png](attachment:Picture2.png)
#
#
# Create a new class for Dolphin which inherits MarineMammal and FlightlessMammal. Use polymorphism and Method Overriding to call get_info() of the other classes to return the following statements. Separate each statetment with \n to add a new line
# <pre>
# Dolphin can swim and lives in the water
# Dolphin can't fly
# Dolphin is warm Blooded
# Dolphin is an Animal
# </pre>
# Use parameterized constructor for all classes. For the class Dolphin, use a parameterless constructor which passes 'Dolphin' to its parent(s) class(es)
#
# get_info method from each class must call its parent class get_info method
#
# **Hint use super() and method resolution order or MRO (obj.__mro__ gives you this info) to figure out the chaining of get_info() methods**

# %%
# Write your solution here
class Animal:
    def __init__(self, name):
        self.name = name
        
    def get_info(self):
        return f"{self.name} is an animal"
    
class Mammal(Animal):
    def __init__(self, name):
        super().__init__(name)
        
    def get_info(self):
        return  f"{self.name} is warm blooded\n" \
                f"{self.name} is an Animal"
    
class MarineMammal(Mammal):
    def __init__(self, name):
        super().__init__(name)
        
    def get_info(self):
        return f"{self.name} can swim and lives in the water\n" \
                f"{self.name} is warm blooded\n" \
                f"{self.name} is an Animal"
    
class FlightlessMammal(Mammal):
    def __init__(self, name):
        super().__init__(name)
        
    def get_info(self):
        return f"{self.name} can't fly\n" \
                f"{self.name} is warm blooded\n" \
                f"{self.name} is an Animal"
    
class Dolphin(MarineMammal, FlightlessMammal):
    def __init__(self):
        super().__init__('Dolphin')
        
    def get_info(self):
        return f"{self.name} can swim and lives in the water\n{self.name} can't fly\n{self.name} is warm blooded\n{self.name} is an Animal"
        
dolphin=Dolphin()
mammal=Mammal("mam")
marine_mammal=MarineMammal('mar_mam')

print(dolphin.get_info())
print(mammal.get_info())
# Out:
# Dolphin can swim and lives in the water
# Dolphin can't fly
# Dolphin is warm blooded
# Dolphin is an Animal
# mam is warm blooded
# mam is an Animal

# %% [markdown]
# #### Question 11&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;(15 Points)
#
# Refer to the image that shows Hybrid Inheritance between the classes TwoDShape,ThreeDShape, Square, Rectangle, Circle, Sphere, Cuboid and Cube
#
#
# ![shapes.png](attachment:shapes.png)
#
#
# Refer to the class code provided
# <pre><code>class TwoDShape:
#     def __init__(self,name):
#         self.name=name
#         self.area=0
#         self.perimeter=0
#
#     def get_area(self):
#         return self._area
#
#     def get_perimeter(self):
#         return self._perimeter
#
#     def calculate_area(self):
#         pass
#
#     def calculate_perimeter(self):
#         pass
#
# class ThreeDShape(TwoDShape):
#     def __init__(self,name):
#         super().__init__(name)
#         self._volume=0
#
#     def calculate_volume(self):
#         pass
#
#     def get_volume(self):
#         return self._volume
#
# class Cirle:
#     pass
#
# class Square:
#     pass
#
# class Rectangle:
#     pass
#
# class Sphere:
#     pass
#
# class Cuboid:
#     pass
#
# class Cube:
#     pass
# </code></pre>
#
# complete the implementation of classes as per the following reqiurements
# <pre>
# Circle
#     +radius
#     +__init__(radius)
#
#
# Rectangle
#     +length
#     +breadth
#     +__init__(length,breadth)
#
#
# Square
#     +length = +breadth
#     +__init__(length)
#
# Sphere
#     +radius
#     +__init__(radius)
#
#
# Cuboid
#     +length
#     +breadth
#     +height
#     +__init__(length,breadth,height)
#
#
# Cube
#     +length = breadth = height
#
# </pre>
# The formulle to calculate the area is given below
# <pre>
# Circle,Sphere = pi x r^2
# Rectangle,Cuboid = length x breadth
# Square,Cube = length^2 = breadth^2
#
# The formulae to calculate the perimeter is given below
# Circle,Sphere = pi x 2 x r
# Rectangle,Cuboid = (length + breadth) x 2
# Square,Cube = length x 4 = breadth x 4
#
# The formulae to calculate the volume is given below
# Sphere = 4/3 x pi x r^3
# Cuboid = length x breadth x height
# Cube = length^3 = height^3 = breadth^3
# </pre>
# **"Note: -- indicates private access modifier and + indicates public access modifier"**
#
# Each class must call it's base class and initialise name with the shape. For example, a Circle object must call TwoDShape constructor with 'Circle' passed as the name. Pay special attention to square and cube for constructor chaining.

# %%
# Write your solution here
import math
class TwoDShape:
    def __init__(self,name):
        self.name=name
        self._area=0
        self._perimeter=0

    def get_area(self):
        return self._area

    def get_perimeter(self):
        return self._perimeter

    def calculate_area(self):
        pass

    def calculate_perimeter(self):
        pass

class ThreeDShape(TwoDShape):
    def __init__(self,name):
        super().__init__(name)
        self._volume=0

    def calculate_volume(self):
        pass

    def get_volume(self):
        return self._volume

class Circle(TwoDShape):
    def __init__(self, radius):
        super().__init__("Circle")
        self.radius = radius
        
    def calculate_area(self):
        self._area = math.pi * (self.radius ** 2)

    def calculate_perimeter(self):
        self._perimeter = math.pi * 2 * self.radius

class Rectangle(TwoDShape):
    def __init__(self, length, breadth):
        super().__init__("Rectangle")
        self.length = length
        self.breadth = breadth
    def calculate_area(self):
        self._area = self.length * self.breadth
    
    def calculate_perimeter(self):
        self._perimeter = 2 * (self.length * self.breadth)
    
class Square(Rectangle):
    def __init__(self, length):
        super(Rectangle, self).__init__("Square")
        self.length = length
        self.breadth = length
    def calculate_area(self):
        self._area = self.length * self.breadth
    
    def calculate_perimeter(self):
        self._perimeter = self.length * 4

class Sphere(ThreeDShape):
    def __init__(self, radius):
        super().__init__("Sphere")
        self.radius = radius

    def calculate_area(self):
        self._area = math.pi * (self.radius ** 2)
    
    def calculate_perimeter(self):
        self._perimeter = math.pi * 2 * self.radius
    
    def calculate_volume(self):
        self._volume = (4/3) * math.pi * (self.radius)**3
    
class Cuboid(ThreeDShape):
    def __init__(self,length,breadth,height):
        super().__init__("Cuboid")
        self.length = length
        self.breadth = breadth
        self.height = height
    
    def calculate_area(self):
        self._area = self.length * self.breadth
    
    def calculate_perimeter(self):
        self._perimeter = 2 * (self.length * self.breadth)
    
    def calculate_volume(self):
        self._volume = self.length * self.breadth * self.height
    
class Cube(Cuboid):
    def __init__(self,length):
        super(Cuboid, self).__init__("Cube")
        self.length = length
        self.breadth = length
        self.height = length
        
    def calculate_area(self):
        self._area = self.length * self.breadth
    
    def calculate_perimeter(self):
        self._perimeter = 2 * (self.length * self.breadth)
    
    def calculate_volume(self):
        self._volume = self.length * self.breadth * self.height

q11c=Circle(2)
q11c.calculate_area()
q11c.calculate_perimeter()
q11r=Rectangle(3,4)
q11r.calculate_area()
q11r.calculate_perimeter()
q11s=Square(3)
q11s.calculate_area()
q11s.calculate_perimeter()
q11sp=Sphere(2)
q11sp.calculate_area()
q11sp.calculate_perimeter()
q11sp.calculate_volume()
cb=Cuboid(3,4,2)
cb.calculate_area()
cb.calculate_perimeter()
cb.calculate_volume()
cu=Cube(3)
cu.calculate_area()
cu.calculate_perimeter()
cu.calculate_volume()
print(q11c.name,q11c.get_area(),q11c.get_perimeter())
(q11c.name,q11c.get_area(),q11c.get_perimeter())==('Circle', 12.566370614359172, 12.566370614359172)
# Out:
# Circle 12.566370614359172 12.566370614359172
# True

# %% [markdown]
# #### Question 12&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;(15 Points)
#
# The college of Wadia has provided the following template for modelling their staff and respective departments
#
# **Note -- indicates private, - indicates protected and + indicates public modifiers**
# <pre>
#
# Department
#     +name
#     -head_of_dept
#     --location
#     --employee_list
#     +__init__(name,location,dept_head_fname,dept_head_lname)
#     +get_head_of_dept()
#     +add_employee(employee)
#     +get_location()
#
#
# Employee
#     static --emp_count
#     +fname
#     +lname
#     -emp_id
#     -contact_no
#     -supervisor
#     +__init__(fname,lname)
#     +get_info()
#     +set_supervisor(supervisor)
#     +get_supervisor()
#     +get_emp_id()
#     +get_contact_no()
#     +set_contact_no()
#
# Supervisor
#     --supervisor_id
#     --reporetees_list
#     +__init__(fname,lname,contact_no,supervisor_id)
#     +get_info()
#     +add_reportee(reportee)
#
# </pre>
#
# Department consists of head_of_department who is an employee and a list of employees. Supervisors are Employees, Employees have a supervisor and supervisors have a list of reportees. Reportee can be a regular employee or a supervisor.
# The class/static variable emp_count must be initialized to 0 and must be incremented before assigning it as emp_id for every employee created. Contact_no must be initiazed to 0 and supervisor must be initialised to None. The 2 lists employee_list and reportee_list must be initialised to empty lists. The methods add_employee and add_reportee must take the respective objects and add them to the respective lists. The method get_info() must print the following lines for Employee. <code>'f{fname} {lname} is an Employee supervised by {supervisor_fname}'</code> if they have a supervisor <code>'f{fname} {lname} is an Employee</code> otherwise. For Supervisors, the method should also print an additional line <code>'They supervise reportee_1fname,reportee_2fname...'</code> for each of their reportees.
#
#
#
#
# After implementing the classes, create the following objects
#     <pre>
#     Department:
#         name:Physics
#         location:Alladeen st, Alladeen B'vrd A1001
#         dept_head:
#             fname: General
#             lname: Alladeen
#
#     Employee:
#         fname:Said
#         lname:Azim
#
#     Employee:
#         fname:Rahim
#         lname:Khan
#
#     Supervisor:
#         fname:Mustafa
#         lname:Akbar
#         supervisor_id:"S001"
#         contact_no:"041267843"
#
# <pre>
# Add Rahim, Said and Mustafa to the Physics department. Assign Mustafa as Azim's supervisor.
# call get_info() for all 3 employees

# %%
phy_dept=None
emp_1=None
emp_2=None
supervisor_3=None

# Write your solution here
class Department:
    def __init__(self,name,location,dept_head_fname,dept_head_lname):
        self.name = name
        self.__head_of_department = Employee(dept_head_fname, dept_head_lname)
        self.__location = location
        self.__employee_list = []
        
    def get_head_of_dept(self):
        return self._head_of_dept
    
    def add_employee(self, employee):
        self.__employee_list.append(employee)
        
    def get_location(self):
        return self.__location


class Employee:
    __emp_count = 0

    def __init__(self,fname,lname):
        self.fname = fname
        self.lname = lname
        self._emp_id = Employee.__emp_count + 1
        Employee.__emp_count += 1
        self._contact_no = 0
        self._supervisor = None
        
    def get_info(self):
        if self._supervisor != None:
            return f'{self.fname} {self.lname} is an Employee supervised by {self._supervisor.fname}'
        return f'{self.fname} {self.lname} is an Employee'
    
    def set_supervisor(self, supervisor):
        self._supervisor = supervisor
        
    def get_supervisor(self):
        return self._supervisor
    
    def get_emp_id(self):
        return self._emp_id
    
    def get_contact_no(self):
        return self._contact_no
    
    def set_contact_no(self, contact_no):
        self._contact_no = contact_no

class Supervisor(Employee): 

    def __init__(self,fname,lname,contact_no,supervisor_id):
        super().__init__(fname, lname)
        self.__supervisor_id = supervisor_id
        self.__reportee_list = []
        
    def get_info(self):
        employee_names = ""
        
        for emp in self.__reportee_list:
            employee_names += emp.fname + " "
        
        return 'They supervise ' + employee_names
    
    def add_reportee(self, reportee):
        self.__reportee_list.append(reportee)

phy_dept = Department("Physics", "Alladeen st, Alladeen B'vrd A1001", "General", "Alladeen")
emp_1 = Employee("Said", "Azim")
emp_2 = Employee("Rahim", "Khan")
supervisor_3 = Supervisor("Mustafa", "Akbar", "041267843", "S001")

supervisor_3.add_reportee(emp_1)
phy_dept.add_employee(emp_1)
phy_dept.add_employee(emp_2)
phy_dept.add_employee(supervisor_3)

emp_1.get_info()
print()
emp_2.get_info()
print()
supervisor_3.get_info()

(emp_1.fname,emp_1.lname)==('Said', 'Azim') and supervisor_3._Supervisor__reportee_list[0].fname=='Said'
(phy_dept._Department__head_of_department.fname,phy_dept._Department__head_of_department.lname)==('General', 'Alladeen')
# Out:
# True

# %% [markdown]
# #### Question 13&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;(15 Points)
#
# KR Health is a company that operates several hospitals. Here is a small part of their OO classes.
#
# <pre>
#     Hospital
#         --location
#         --total_beds
#         --wards_dict
#         +register_ward(name,ward_type,nusre,no_of_beds,**kwargs)
#         +__init__(location,beds)
#         +get_location()
#         +get_total_beds()
#         +get_wards()
#
#     GeneralWard
#         -no_of_beds
#         -name
#         -patient_list
#         -nurse
#         +__init__(name,no_of_beds,nurse)
#         +admit_patient(patient)
#         +discharge_patient(patient)
#         +get_info()
#
#     ICUWard
#         -doctor_in_charge
#         +__init__(name,no_of_beds,nurse,doctor_in_charge)
#         +get_info()
#
#     Patitent
#         +name
#         +contact_no
#         +doctor_name
#         +__init__(name,contact_no,doctor_name)
# </pre>
#
# The Hospital has Wards. Initialise the wards to an empty dictionary.The wards are identified by their name. When a new ward is added, use <code>register_ward()</code> to create a ward object and add it to the dictionary <code>wards</code>. If the ward type is `Normal` create a GeneralWard, else if the type is `ICU` create a ICUWard. ICUWard inherits GeneralWard. The method `get_info()` must print the message `f'Ward {name} is currently occupied by patient_1name..... and looked after by {nurse}'.` if the patient_list is not empty. Otherwise, print `Ward {name} is empty`. For ICUWard, the additional line `f'Ward is overseen by Dr. {doctor_in_charge}'` must be printed. The methods <code>admit_patient()</code> and <code>discahrge_patient()</code> must add and remove patient from the patient_list respectively. If the bed capacity is exceeded or if the patient does not exist in the patient list respectively, return False else return True.
#
# After completing the class implementation, create the following objects
# <pre>
#     Hospital:
#         no_of_beds:8
#         location:13 Abardeen Ave, NYCity 1234
#
#     Patient:
#         name:Jing
#         doctor_name:Ronny cheng
#         contact_no:123456789
#
#     Patient:
#         name:Xi Li
#         doctor_name:Ronny cheng
#         contact_no:987654321
#
#     Also register a general ward with the following details
#         beds: 5
#         name: Bradley general ward
#         nurse: Wendy
#
#     and an ICUWard with the following details
#         beds: 3
#         name: Cooper intensive care ward
#         nurse: William
#         doctor_in_charge:  Whittaker</pre>
#
# Register Jing to the ICU ward and Xi to the intensive ward. Identify the relation_hosp_ward between Hospital and Ward and populate the variable relation_hosp_patient with one of the values <code>['Inheritance','Composition','Arrgregation']</code>. Identify the relation between Patient and Ward and populate the variable relation_patient_ward

# %%
# Write your solution here
relation_hosp_ward='Composition'
relation_hosp_paitent='Arrgregation'
relation_patient_ward='Arrgregation'
p1=None
p2=None
hosp = None

class Hospital:

    def __init__(self,location,beds):
        self.__location = location
        self.__total_beds = beds
        self.__wards_dict = dict()
            
    def register_ward(self,name,ward_type,nurse,no_of_beds,**kwargs):
        if ward_type == "Normal":
            ward = GeneralWard(name, no_of_beds, nurse)
        else:
            ward = ICUWard(name, no_of_beds, nurse, kwargs['doctor_in_charge'])
        self.__wards_dict[name] = ward
        
    def get_location(self):
        return self.__location
        
    def get_total_beds(self):
        return self.__total_beds
        
    def get_wards(self):
        return self.__wards_dict

class GeneralWard:

    def __init__(self,name,no_of_beds,nurse):
        self._name = name
        self._no_of_beds = no_of_beds
        self._nurse = nurse
        self._paitent_list = []
        
    def admit_paitent(self,patient):
        if len(self._paitent_list) == self._no_of_beds:
            return False
        self._paitent_list.append(patient)
        return True
    
    def discharge_patient(patient):
        self._paitent_list.remove(patient)
        
    def get_info(self):
        if (len(self._paitent_list) != 0):
            patient_names = ""
            for patient in self._paitent_list:
                patient_names += patient.name + " "
            return f'Ward {self._name} is currently occupied by {patient_names}and looked after by {self._nurse}'
    
        return f'Ward {self._name} is empty'

class ICUWard(GeneralWard):
    def __init__(self,name,no_of_beds,nurse,doctor_in_charge):
        super().__init__(name,no_of_beds,nurse)
        self._doctor_in_charge = doctor_in_charge
        
    def get_info(self):
        if (len(self._paitent_list) != 0):
            patient_names = ""
            for patient in self._paitent_list:
                patient_names += patient.name + " "
            return f'Ward {self._name} is currently occupied by {patient_names}and looked after by {self.nurse}\nWard is overseen by Dr. {self._doctor_in_charge}'
    
        return f'Ward {self._name} is empty' + f'\nWard is overseen by Dr. {self._doctor_in_charge}'
        
class Paitent:
    def __init__(self,name,contact_no,doctor_name):
        self.name = name
        self.contact_no = contact_no
        self.doctor_name = doctor_name

hosp = Hospital("13 Abardeen Ave, NYCity 1234", 8)
hosp.register_ward('Bradley general ward','Normal','Wendy',5)
hosp.register_ward('Cooper intensive care ward','','William',3, doctor_in_charge='Whittaker')
hosp.get_wards()['Bradley general ward'].get_info()
hosp.get_wards()['Cooper intensive care ward'].get_info()
p1=Paitent('Jing',123456789,'Ronny cheng')
p2=Paitent('Xi Li',987654321,'Ronny cheng')
hosp.get_wards()['Bradley general ward'].admit_paitent(p1)
hosp.get_wards()['Cooper intensive care ward'].admit_paitent(p2)
[hosp.get_wards()['Bradley general ward'].admit_paitent(Paitent('a',1,'R')) for _ in range(6)]==[True, True, True, True, False, False]
# Out:
# True

# %% [markdown]
# #### Question 14&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;(15 Points)
#
# Meg's Dogs is a dog grooming service in Adelaide. The company that was hired to help them with operations has come up with the following template for real-world entities.
#
# <pre>
#     Client
#         --contact_no
#         --name
#         --pet
#         +__init__(name,contact_no,pet_name,pet_dob,pet_type,pet_breed,**kwargs)
#         +get_contact_no()
#         +get_name()
#         +get_pet()
#
#     Dog
#         -name
#         -dob
#         -breed
#         +get_name()
#         +get_breed()
#         +__init__(name,dob,breed)
#
#     DoubleCoatedDog
#         --double_coat_type
#         --hair_length
#         --hair_type
#         +__init__(name,dob,breed,double_coat_type,hair_length,hair_type)
#         +get_double_coat_type()
#         +get_hair_length()
#         +get_hair_type()
#
#     GroomAppointment
#         --datetime
#         --client
#         +__init__(client,datetime)
#         +perform_grooming()
#
# </pre>
#
# DoubleCoatedDog is a class for special type of dogs that have a double coat (like huskies). They might have a summer or winter double coat. Their hair length can be medium or long. Their hair type can be straight or curly. The method perform_grooming must print the following statements.
# <pre>
# <code>
# 'Welcome {client_name}, your pet {pet_name} will be groomed today'</code>
# If the type of pet is Dog then print <code>'{pet_name} will be bathed, dried (low intensity drier), brushed and trimmed'</code>
# If the type is DoubleCoatedDog, print<code>'{pet_name} will be bathed, dried (high intensity drier), given a chemspray, brushed and trimmed'</code> if the Dog has curly hair, print the line <code>'{pet_name} will be bathed, dried (high intensity drier), given a chemspray, brushed, dematted and trimmed'</code>
# </pre>
# **Hint use isinstance(obj,classname) to identify if an objects belongs to a class**
#
# All string comparisons must be case insensitive
#
# After completing the class implementation, create the following objects
# <pre>
#     Client:
#         name:Joe
#         contact_no:123456789
#         pet_type:Dog
#         pet_name:Swanson
#         pet_breed:Bulldog
#         pet_dob:02/02/2000
#
#     Client:
#         name:Peter
#         contact_no:04231567
#         pet_type:DoubleCoatedDog
#         pet_name:Brian
#         pet_breed:ShitzuLabCross
#         pet_dob:03/03/2000
#         pet_hair_type:flat
#         pet_hair_length:medium
#         pet_double_coat_type:summer
#
# </pre>
#
# Also create GroomingAppointment for Joe on '26/05/2022 2pm' and Peter on '26/05/2022 4pm'. Call perform_grooming() on both appointments.
#
# **Hint lookup datetime.datetime.strptime for creating datetime from string**
#
# Identify the relation between Client and Pet and populate the variable relation_client_pet with one of the values <code>['Inheritance','Composition','Aggregation']</code>. Identify the relation between GroomAppointment and Client and populate the variable relation_groom_client

# %%
# Write your solution here
import datetime

relation_client_pet="Composition"
relation_groom_client="Aggregation"
client1=None
client2=None

groom1=None
groom2=None

class Client:
        
    def __init__(self,name,contact_no,pet_name,pet_dob,pet_type,pet_breed,**kwargs):
        self.__name = name
        self.__contact_no = contact_no
        
        if pet_type.lower() == 'Dog'.lower():
            pet = Dog(pet_name, pet_dob, pet_breed)
        elif pet_type.lower() == 'DoubleCoatedDog'.lower():
            pet = DoubleCoatedDog(pet_name, pet_dob, pet_breed, kwargs['double_coat_type'], kwargs['hair_length'], kwargs['hair_type'])
        self.__pet = pet
        
    def get_contact_no(self):
        return self.__contact_no
    
    def get_name(self):
        return self.__name
    
    def get_pet(self):
        return self.__pet

class Dog:
      
    def __init__(self,name,dob,breed):
        self._name = name
        self._dob = dob
        self._breed = breed
    
    def get_name(self):
        return self._name
    
    def get_breed(self):
        return self._breed

class DoubleCoatedDog(Dog):
    def __init__(self,name,dob,breed,double_coat_type,hair_length,hair_type):
        super().__init__(name, dob, breed)
        self.__double_coat_type = double_coat_type
        self.__hair_length = hair_length
        self.__hair_type = hair_type
    
    def get_double_coat_type(self):
        return self.__double_coat_type
    
    def get_hair_length(self):
        return self.__hair_length
    
    def get_hair_type(self):
        return self.__hair_type

class GroomAppointment:
    def __init__(self, client,datetime):
        self.__client = client
        self.__datetime = datetime
    def perform_grooming(self):
        client = self.__client
        pet = self.__client.get_pet()
        result = f'Welcome {client.get_name()}, your pet {pet.get_name()} will be groomed today\n'
        if isinstance(pet, Dog):
            result += f'{pet.get_name()} will be bathed, dried (low intensity drier), brushed and trimmed'
        elif isinstant(pet, DoubleCoatedDog) and pet.get_hair_type.lower() == 'curly':
            result += f'{pet.get_name()} will be bathed, dried (high intensity drier), given a chemspray, brushed, dematted and trimmed'
        elif isinstant(pet, DoubleCoatedDog):
            result += f'{pet.get_name()} will be bathed, dried (high intensity drier), given a chemspray, brushed and trimmed'
        
        print(result)

client1=Client('Joe',123456789,'Swanson','02/02/2000','Dog','Bulldog')
client2=Client('Peter',4231567,'Brian','03/03/2000','DoubleCoatedDog','ShitzuLabCross',
           hair_type='flat',hair_length='medium',double_coat_type='summer')

groom1 = GroomAppointment(client1, datetime.datetime(2022,5,26,hour=14)) 
groom1.perform_grooming()

print()
groom2 = GroomAppointment(client2, datetime.datetime(2022,5,26,hour=16))
groom2.perform_grooming()

print(list(client1.__dict__.keys()))
# Out:
# Welcome Joe, your pet Swanson will be groomed today
# Swanson will be bathed, dried (low intensity drier), brushed and trimmed
#
# Welcome Peter, your pet Brian will be groomed today
# Brian will be bathed, dried (low intensity drier), brushed and trimmed
# ['_Client__name', '_Client__contact_no', '_Client__pet']
